# %%
import pandas as pd

# %%
my_df = pd.read_csv('csv_data/survey_results_public.csv')
my_df_short = my_df.loc[0:12,['DevType','CareerSat','LastHireDate','ConvertedComp']]
my_df_short
# Out:
#                                               DevType              CareerSat
# 0                                                 NaN                    NaN  \
# 1   Developer, desktop or enterprise applications;...                    NaN
# 2   Designer;Developer, back-end;Developer, front-...     Slightly satisfied
# 3                               Developer, full-stack         Very satisfied
# 4   Academic researcher;Developer, desktop or ente...      Very dissatisfied
# 5   Data or business analyst;Data scientist or mac...         Very satisfied
# 6                       Designer;Developer, front-end     Slightly satisfied
# 7      Developer, back-end;Engineer, site reliability                    NaN
# 8   Database administrator;Developer, back-end;Dev...     Slightly satisfied
# 9   Data or business analyst;Data scientist or mac...  Slightly dissatisfied
# 10                                                NaN                    NaN
# ...

# %%
my_df_short['CareerSat'] == 'Slightly satisfied'
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# Name: CareerSat, dtype: bool

# %%
my_df_short[my_df_short == 'Slightly satisfied']
# Out:
#    DevType           CareerSat LastHireDate  ConvertedComp
# 0      NaN                 NaN          NaN            NaN
# 1      NaN                 NaN          NaN            NaN
# 2      NaN  Slightly satisfied          NaN            NaN
# 3      NaN                 NaN          NaN            NaN
# 4      NaN                 NaN          NaN            NaN
# 5      NaN                 NaN          NaN            NaN
# 6      NaN  Slightly satisfied          NaN            NaN
# 7      NaN                 NaN          NaN            NaN
# 8      NaN  Slightly satisfied          NaN            NaN
# 9      NaN                 NaN          NaN            NaN
# 10     NaN                 NaN          NaN            NaN
# 11     NaN                 NaN          NaN            NaN
# 12     NaN                 NaN          NaN            NaN

# %%
my_df_short[my_df_short == 'Slightly satisfied']['CareerSat']
# Out:
# 0                    NaN
# 1                    NaN
# 2     Slightly satisfied
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6     Slightly satisfied
# 7                    NaN
# 8     Slightly satisfied
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# Name: CareerSat, dtype: object

# %%
my_df_short[my_df_short['CareerSat'] == 'Slightly satisfied']
# Out:
#                                              DevType           CareerSat
# 2  Designer;Developer, back-end;Developer, front-...  Slightly satisfied  \
# 6                      Designer;Developer, front-end  Slightly satisfied
# 8  Database administrator;Developer, back-end;Dev...  Slightly satisfied
#
#                                         LastHireDate  ConvertedComp
# 2                                      1-2 years ago         8820.0
# 6  NA - I am an independent contractor or self em...            NaN
# 8                               Less than a year ago        95179.0

# %%
a = my_df_short['LastHireDate'].str.contains("year",na=False)
a
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# Name: LastHireDate, dtype: bool

# %%
my_df_short[a]
# Out:
#                                               DevType              CareerSat
# 2   Designer;Developer, back-end;Developer, front-...     Slightly satisfied  \
# 3                               Developer, full-stack         Very satisfied
# 4   Academic researcher;Developer, desktop or ente...      Very dissatisfied
# 5   Data or business analyst;Data scientist or mac...         Very satisfied
# 8   Database administrator;Developer, back-end;Dev...     Slightly satisfied
# 9   Data or business analyst;Data scientist or mac...  Slightly dissatisfied
# 11  Data or business analyst;Data scientist or mac...                    NaN
# 12  Data or business analyst;Database administrato...         Very satisfied
#
#             LastHireDate  ConvertedComp
# 2          1-2 years ago         8820.0
# 3   Less than a year ago        61000.0
# 4   Less than a year ago            NaN
# 5          1-2 years ago       366420.0
# 8   Less than a year ago        95179.0
# ...
