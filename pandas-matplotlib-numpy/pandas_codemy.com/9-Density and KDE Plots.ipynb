# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
my_df= pd.DataFrame(randn(500,4),columns=['Mon','Tue',"Wen",'Thu'])
my_df
# Out:
#           Mon       Tue       Wen       Thu
# 0   -0.159990 -1.307039 -0.708810 -0.524673
# 1   -1.100756 -1.524248  1.052980 -0.605466
# 2    0.588916 -1.236807  1.967235 -0.050973
# 3   -0.270010 -0.387469 -2.183267 -1.894608
# 4   -0.345445 -1.602123 -1.524302 -0.611749
# ..        ...       ...       ...       ...
# 495 -0.807564  0.087801  1.795306 -0.313838
# 496  0.719333 -0.070114  0.116338 -0.722513
# 497 -1.835740 -1.190821  0.388879 -0.034290
# 498 -0.087356 -0.323895 -1.214652 -0.730189
# 499  1.028562  1.339256  0.438430  0.747487
#
# [500 rows x 4 columns]

# %%
##kernel density plot ,requires scipy installed
my_df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot.density(lw=4,alpha=0.6)
# Out:
# <Axes: ylabel='Density'>

# %%
my_df["Tue"].plot.density(lw=6)
# Out:
# <Axes: ylabel='Density'>
