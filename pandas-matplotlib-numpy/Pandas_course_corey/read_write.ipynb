# %%
import pandas as pd


df = pd.read_csv('csv_data/survey_results_public.csv',index_col='Respondent')
df_schematic = pd.read_csv('csv_data/survey_results_schema.csv',index_col='Column')

pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
india_df = df[df['Country'] == 'India']

# %%
india_df.to_csv('csv_data/modified.csv')

# %%
india_df.to_csv('csv_data/modified.tsv',sep='\t')

# %%
# ##for excell pip install xlwt for older excel formatn and then openpyxl for newer xlsx format and xlrd to read excell format

##can read more about to_excell like writing to different sheets in it's relevant documentation
india_df.to_excel('csv_data/modified.xlsx')

# %%
pd.read_excel('csv_data/modified.xlsx',index_col='Country')
# Out:
#          Respondent                              MainBranch Hobbyist  \
# Country
# India             8             I code primarily as a hobby      Yes
# India            10          I am a developer by profession      Yes
# India            15  I am a student who is learning to code      Yes
# India            50          I am a developer by profession      Yes
# India            65          I am a developer by profession      Yes
# ...             ...                                     ...      ...
# India         77339                                     NaN      Yes
# India         79795                                     NaN      Yes
# India         83862                                     NaN      Yes
# India         84299                                     NaN      Yes
# India         86012                                     NaN      Yes
#
#                                                OpenSourcer  \
# Country
# ...

# %%
india_df.to_json('csv_data/modified.json')

# %%
india_df.to_json('csv_data/modified_list_like.json',orient='records',lines=True)  #list like

# %%
pd.read_json('csv_data/modified_list_like.json',orient='records',lines=True)

# %%
###SQL  pip install SQLAlchemy  psycopg2-binary and watch rest of corey chafer video
