# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread("assets/Photos/cats.jpg")

cv.imshow("image", img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
##in this image pixel intensity is in 60ish range 
img = cv.imread("assets/Photos/cats.jpg")
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
# cv.imshow("gray", gray)
# cv.waitKey(0)
# cv.destroyAllWindows()

gray_hist = cv.calcHist([gray],[0],None,[256], [0,256])

plt.figure(figsize=(10,7))
plt.title("Grayscale Histogram")
plt.xlabel("Bins")
plt.ylabel("# of pixels")
plt.plot(gray_hist)
# plt.xlim([0,256])

# %%
## another image
img = cv.imread("assets/Photos/cats 2.jpg")
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

gray_hist = cv.calcHist([gray],[0],None,[256], [0,256])

plt.figure(figsize=(10,7))
plt.title("Grayscale Histogram")
plt.xlabel("Bins")
plt.ylabel("# of pixels")
plt.plot(gray_hist)
# plt.xlim([0,256])

# %%
colored_hist_red = cv.calcHist([img],[2],None,[256], [0,256])

plt.figure(figsize=(10,7))
plt.title("Grayscale Histogram")
plt.xlabel("Bins")
plt.ylabel("# of pixels")
plt.plot(gray_hist)
# plt.xlim([0,256])

# %% [markdown]
# # colored histogram

# %%
img = cv.imread("assets/Photos/cats.jpg")
blank = np.zeros(img.shape[:2], dtype="uint8")

mask = cv.circle(blank, (img.shape[1]//2, img.shape[0]//2), 100, 255, -1 )
cv.imshow("mask", mask)

masked = cv.bitwise_and(img, img, mask=mask)

cv.imshow("masked", masked)
cv.imshow("img", img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# no mask
colors = ("b", "g", "r")

plt.figure(figsize=(10, 7))
plt.title("Colored Histogram no mask")
plt.xlabel("Bins")
plt.ylabel("# of pixels")
for i, col in enumerate(colors):
    hist = cv.calcHist([img], [i], None, [256], [0,256])
    
    plt.plot(hist, color=col)
    plt.xlim([0,256])

# %%
## with mask
colors = ("b", "g", "r")

plt.figure(figsize=(10, 7))
plt.title("Colored Histogram with mask")
plt.xlabel("Bins")
plt.ylabel("# of pixels")
for i, col in enumerate(colors):
    hist = cv.calcHist([img], [i], mask, [256], [0,256])
    
    plt.plot(hist, color=col)
    plt.xlim([0,256])
